# %% [markdown]
# <a href="https://colab.research.google.com/github/mhwayez/331_assembly/blob/master/Real_Time_Twitter_sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install tweepy

# %%
# !pwd
# Out:
# /content

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
consumer_key = "Mt4H0fXDr0gQ7ZsZrBpdrV7ux"
consumer_secret = "qioTnREvr75pW0xpUAGqg6VVDY47esxv6qYgmTrH1liXeiTS31"
access_token = "2936080296-934tDdso4SC1u6EYOaIe9Q7JgUxdLVXpLG0NSnt"
access_token_secret = "7RBBo1dWXgpr8mGrwuSXX1fwRI6Qo7Y1RYS61KCbvVmXk"

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
api = tweepy.API(auth)

# %% [markdown]
# # My Timeline Twitters

# %%
tweets = api.home_timeline()

# %%
for tweet in tweets:
  print(tweet.text)
# Out:
# UK's Rees-Mogg says 'common sense' could have saved Grenfell victims https://t.co/7zY0SUBEJU https://t.co/WwYJINSAHd
# These brides went unconventional and wore gorgeous golden wedding gowns. https://t.co/47iOa2jZYj
# Latino man suffers second-degree burns in what he calls a hate-fueled attack https://t.co/HSvCdOwlkE
# What’s the potential harm to groundwater quality in an era of shale gas exploration? This Thursday we explore the a… https://t.co/X3TBFlogUk
# While U.S. investigators have focused on whether Juul’s marketing targeted teens, @Reuters investigation finds that… https://t.co/yRokOXASas
# The #DaytimeEmmys' award for outstanding musical performance in a daytime program has been eliminated https://t.co/fa2AVSuQI6
# The wax palm, Colombia's national tree, is endangered. With decades of guerrilla war in retreat, scientists are red… https://t.co/MdbbhIQxln
# ...

# %% [markdown]
# # GET Twitter Streaming and do sentiment analysis

# %%
from tweepy import Stream
from tweepy import StreamListener
import json
from textblob import TextBlob

# %%
import re

# %%
import csv

# %%
trump = 0 
warren = 0 


header_name = ['Trump',"Warren"]
with open('/content/sentiment.csv','w') as file: 
  writer = csv.DictWriter(file,fieldnames=header_name)
  writer.writeheader()
class Listner(StreamListener):


  def on_data(self,data):
    raw_twitts = json.loads(data)
    try:
      tweets = raw_twitts['text']
      tweets = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweets).split())
      tweets = ' '.join(re.sub('RT',' ', tweets).split())

      blob = TextBlob(tweets.strip())

      global trump
      global warren


      trump_sentiment = 0
      warren_sentiment = 0


      for sent in blob.sentences:
        if "Trump" in sent and "Warren" not in sent:
          trump_sentiment = trump_sentiment + sent.sentiment.polarity
        else:
          warren_sentiment = warren_sentiment + sent.sentiment.polarity

      trump = trump + trump_sentiment
      warren = warren + warren_sentiment

      with open('sentiment.csv', 'a') as file:
                writer = csv.DictWriter(file, fieldnames=header_name)
                info = {
                    'Trump': trump,
                    'Warren': warren
                }
                writer.writerow(info)


      print(tweets)
      print()
    except:
      print('Error got but')
  

  def on_error(self,status):
    print(status)

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)

# %%
twitter_stream = Stream(auth,Listner())
twitter_stream.filter(track = ['Trump','Warren'])
# Out:
# Rand Paul is Trump s newest fart sniffer
#
# Trump supporters reinforce the stereotype that Americans are stupid
#
# dow This is where we are Aim higher America
#
# Trump seems to have used threatening language to a foreign leader trashing his own US Ambassador This career foreign serv
#
# Hey Big Blue Nation the cops of Lexington Ky are not protecting its people or even its visitors Instead they allow
#
# I m ready to throw hands
#
# Bill Clinton Credibly Accused of Rape Investigation Is Overdue
#
# We spent the hour talking about Donald Trump s corruption There s something else too that we don t talk about as often
#
# In May 2018 Fox News ran a segment about how former Congressman Pete Sessions R TX sent SoS Pompeo an urgent letter
#
# A decis o final vai depender de quem vencer ss elei es presidenciais norte americanas em 2020
#
# A racist in Wisconsin threw battery acid in a Latino man s face after accusing him of being in the country illegally The vi
#
# ...

# %%
from itertools import count
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %%
plt.style.use('fivethirtyeight')

# %%
# !pwd

# %%
frame_len = 10000

fig = plt.figure(figsize=(9,6))

def animate(i):
    data = pd.read_csv('sentiment.csv')
    y1 = data['Trump']
    y2 = data['Warren']

    if len(y1)<=frame_len:
        plt.cla()
        plt.plot(y1, label='Donald Trump')
        plt.plot(y2, label='Elizabeth Warren')
    else:
        plt.cla()
        plt.plot(y1[-frame_len: ], label='Donald Trump')
        plt.plot(y2[-frame_len: ], label='Elizabeth Warren')
    
    plt.legend(loc='upper left')
    plt.tight_layout()


ani = FuncAnimation(plt.gcf(), animate, interval=1000)
